# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# path to your project on Google Drive
DRIVE_PATH = 'drive/MyDrive/Projects/' 
# replace with your Github username 
GIT_USERNAME = "szat" 
# definitely replace with your
GIT_TOKEN = "b78f2c904cfeb583cb5a60de1d98635083139b4e"  
# Replace with your github repository in this case we want 
PROJECT_NAME = "ColabTemplate" 
PROJECT_PATH = DRIVE_PATH + PROJECT_NAME
print("PROJECT_PATH: ", PROJECT_PATH)

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + PROJECT_NAME + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  drive/MyDrive/Projects/ColabTemplate
# GIT_PATH:  https://b78f2c904cfeb583cb5a60de1d98635083139b4e@github.com/szat/ColabTemplate.git

# %%
cd $PROJECT_PATH
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Projects/ColabTemplate'
# /content/drive/My Drive/Projects/ColabTemplate/colab

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .

# %%
# !git config user.email "artabalt@gmail.com"
# !git config user.name "szat"
# !git commit -m "trying this"
# Out:
# [main c156786] trying this
#  1 file changed, 1 insertion(+)
#  create mode 100644 init_project.ipynb

# %%
# !git push
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.54 KiB | 315.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/szat/ColabTemplate.git
#    77757ac..c156786  main -> main

# %%
ls
# Out:
# drive/  sample_data/

# %%
mkdir colab

# %%
mv init_project.ipynb
